# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/hp/Downloads/Data Sets/bank_customer_data.csv')

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47          blue   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57          blue   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  int64
# dtypes: int64(8), object(9)
# memory usage: 5.9+ MB

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
sns.pairplot(df)

# %%
sns.barplot(x='y',y='age',data=df)

# %%
sns.barplot(x='y',y='job',data=df)

# %%
sns.barplot(x='y',y='marital',data=df)

# %%
sns.barplot(x='y',y='default',data=df)

# %%
sns.barplot(x='housing',y='y',data=df)

# %%
sns.barplot(x='loan',y='y',data=df)

# %%
sns.barplot(x='contact',y='y',data=df)

# %%
sns.barplot(x='month',y='y',data=df)

# %%
df['job'].value_counts()
# Out:
# blue            9732
# management      9458
# technician      7597
# admin           5171
# services        4154
# retired         2264
# self            1579
# entrepreneur    1487
# unemployed      1303
# housemaid       1240
# student          938
# unknown          288
# Name: job, dtype: int64

# %%
# Now we have different different methods to fill the unknown values- Delete the record,Statistics,Applying sepearte model

# %%
df #- 0,2,3,4,5,month - independent ----------job - dependent
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47          blue   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57          blue   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df['job'].value_counts()
# Out:
# blue            9732
# management      9458
# technician      7597
# admin           5171
# services        4154
# retired         2264
# self            1579
# entrepreneur    1487
# unemployed      1303
# housemaid       1240
# student          938
# unknown          288
# Name: job, dtype: int64

# %%
df2=df

# %%
df2
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47          blue   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57          blue   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
y_test=df2[df2['job']=='unknown'].index

# %%
y_test
# Out:
# Int64Index([    4,   216,   354,   876,  1072,  1292,  2046,  2723,  2841,
#              2848,
#             ...
#             44405, 44544, 44651, 44656, 44681, 44714, 44742, 44970, 45141,
#             45186],
#            dtype='int64', length=288)

# %%
for i in df2.index:
    if df2.at[i,'job']=='unknown':
        df2=df2.drop(index=i)

# %%
df2 #Training model
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47          blue   married    unknown      no     1506     yes   no
# 5       35    management   married   tertiary      no      231     yes   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57          blue   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df1=df

# %%
df1
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47          blue   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57          blue   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
y_train=df2['job']

# %%
y_train
# Out:
# 0          management
# 1          technician
# 2        entrepreneur
# 3                blue
# 5          management
#              ...
# 45206      technician
# 45207         retired
# 45208         retired
# 45209            blue
# 45210    entrepreneur
# Name: job, Length: 44923, dtype: object

# %%
df2=df2.drop(columns=['job','default','loan','contact','day','month','duration','campaign','pdays','previous','poutcome','y'])

# %%
df2
# Out:
#        age   marital  education  balance housing
# 0       58   married   tertiary     2143     yes
# 1       44    single  secondary       29     yes
# 2       33   married  secondary        2     yes
# 3       47   married    unknown     1506     yes
# 5       35   married   tertiary      231     yes
# ...    ...       ...        ...      ...     ...
# 45206   51   married   tertiary      825      no
# 45207   71  divorced    primary     1729      no
# 45208   72   married  secondary     5715      no
# 45209   57   married  secondary      668      no
# 45210   37   married  secondary     2971      no
#
# [44923 rows x 5 columns]

# %%
X_train=df2

# %%
X_train
# Out:
#        age   marital  education  balance housing
# 0       58   married   tertiary     2143     yes
# 1       44    single  secondary       29     yes
# 2       33   married  secondary        2     yes
# 3       47   married    unknown     1506     yes
# 5       35   married   tertiary      231     yes
# ...    ...       ...        ...      ...     ...
# 45206   51   married   tertiary      825      no
# 45207   71  divorced    primary     1729      no
# 45208   72   married  secondary     5715      no
# 45209   57   married  secondary      668      no
# 45210   37   married  secondary     2971      no
#
# [44923 rows x 5 columns]

# %%
df1
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47          blue   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57          blue   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
X_test=df1.drop(df1[df1['job']!='unknown'].index,axis=0)

# %%
X_test
# Out:
#        age      job   marital education default  balance housing loan  \
# 4       33  unknown    single   unknown      no        1      no   no
# 216     47  unknown   married   unknown      no       28      no   no
# 354     59  unknown  divorced   unknown      no       27      no   no
# 876     37  unknown    single   unknown      no      414     yes   no
# 1072    29  unknown    single   primary      no       50     yes   no
# ...    ...      ...       ...       ...     ...      ...     ...  ...
# 44714   45  unknown   married  tertiary      no      406      no   no
# 44742   64  unknown   married   unknown      no     2799      no   no
# 44970   28  unknown    single   unknown      no      326      no   no
# 45141   77  unknown   married   unknown      no      397      no   no
# 45186   59  unknown   married   unknown      no     1500      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  y
# ...

# %%
y=X_test['job']

# %%
X_test.drop('job',axis=1)
# Out:
#        age   marital education default  balance housing loan    contact  day  \
# 4       33    single   unknown      no        1      no   no    unknown    5
# 216     47   married   unknown      no       28      no   no    unknown    5
# 354     59  divorced   unknown      no       27      no   no    unknown    5
# 876     37    single   unknown      no      414     yes   no    unknown    7
# 1072    29    single   primary      no       50     yes   no    unknown    7
# ...    ...       ...       ...     ...      ...     ...  ...        ...  ...
# 44714   45   married  tertiary      no      406      no   no   cellular    7
# 44742   64   married   unknown      no     2799      no   no  telephone    9
# 44970   28    single   unknown      no      326      no   no   cellular   11
# 45141   77   married   unknown      no      397      no   no  telephone    8
# 45186   59   married   unknown      no     1500      no   no   cellular   16
#
# ...

# %%
X_train
# Out:
#        age   marital  education  balance housing
# 0       58   married   tertiary     2143     yes
# 1       44    single  secondary       29     yes
# 2       33   married  secondary        2     yes
# 3       47   married    unknown     1506     yes
# 5       35   married   tertiary      231     yes
# ...    ...       ...        ...      ...     ...
# 45206   51   married   tertiary      825      no
# 45207   71  divorced    primary     1729      no
# 45208   72   married  secondary     5715      no
# 45209   57   married  secondary      668      no
# 45210   37   married  secondary     2971      no
#
# [44923 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
X_train['marital']=le.fit_transform(X_train['marital'])
X_train['education']=le.fit_transform(X_train['education'])
X_train['housing']=le.fit_transform(X_train['housing'])

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.score(X_train,y_train)
# Out:
# 0.9456403178772567

# %%
X_test['marital']=le.fit_transform(X_test['marital'])
X_test['education']=le.fit_transform(X_test['education'])
X_test['housing']=le.fit_transform(X_test['housing'])

# %%
X_test
# Out:
#        age      job  marital  education default  balance  housing loan  \
# 4       33  unknown        2          3      no        1        0   no
# 216     47  unknown        1          3      no       28        0   no
# 354     59  unknown        0          3      no       27        0   no
# 876     37  unknown        2          3      no      414        1   no
# 1072    29  unknown        2          0      no       50        1   no
# ...    ...      ...      ...        ...     ...      ...      ...  ...
# 44714   45  unknown        1          2      no      406        0   no
# 44742   64  unknown        1          3      no     2799        0   no
# 44970   28  unknown        2          3      no      326        0   no
# 45141   77  unknown        1          3      no      397        0   no
# 45186   59  unknown        1          3      no     1500        0   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  y
# ...

# %%
for i in X_test.index:
    pred = clf.predict(pd.DataFrame(X_test.loc[i:i+1][['age','marital','education','balance','housing']]))
    X_test.loc[i,'job']=pred[0]

# %%
for i in df.index:
    if df.at[i,'job']=='unknown':
        df.at[i,'job']=X_test.at[i,'job']

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47          blue   married    unknown      no     1506     yes   no
# 4       33       student    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57          blue   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df['job'].value_counts()
# Out:
# blue            9798
# management      9512
# technician      7634
# admin           5198
# services        4173
# retired         2300
# self            1586
# entrepreneur    1498
# unemployed      1312
# housemaid       1257
# student          943
# Name: job, dtype: int64

# %%
# we have successfully fill the unknown values using seprate decision tree

# %%
X=df
y=df['y']

# %%
X['marital'].value_counts()
# Out:
# married     27214
# single      12790
# divorced     5207
# Name: marital, dtype: int64

# %%
X['default'].value_counts()
# Out:
# no     44396
# yes      815
# Name: default, dtype: int64

# %%
df['education'].value_counts()
# Out:
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64

# %%
for i in df.index:
    if df.at[i,'education']=='unknown':
        df.at[i,'education']='secondary'

# %%
df['education'].value_counts()
# Out:
# secondary    25059
# tertiary     13301
# primary       6851
# Name: education, dtype: int64

# %%
X['housing'].value_counts()
# Out:
# yes    25130
# no     20081
# Name: housing, dtype: int64

# %%
X['loan'].value_counts()
# Out:
# no     37967
# yes     7244
# Name: loan, dtype: int64

# %%
X['contact'].value_counts()
# Out:
# cellular     29285
# unknown      13020
# telephone     2906
# Name: contact, dtype: int64

# %%
for i in df.index:
    if df.at[i,'contact']=='unknown':
        df.at[i,'contact']='cellular'

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47          blue   married  secondary      no     1506     yes   no
# 4       33       student    single  secondary      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57          blue   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
X['month'].value_counts()
# Out:
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: month, dtype: int64

# %%
X['poutcome'].value_counts()
# Out:
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: poutcome, dtype: int64

# %%
df.drop(columns=['poutcome'],inplace=True)

# %%
# This is our final dataset

# %%
X
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47          blue   married  secondary      no     1506     yes   no
# 4       33       student    single  secondary      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57          blue   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df['y'].value_counts() #shows inbalance dataset
# Out:
# 0    39922
# 1     5289
# Name: y, dtype: int64

# %%
X
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47          blue   married  secondary      no     1506     yes   no
# 4       33       student    single  secondary      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57          blue   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
X=pd.get_dummies(X)

# %%
X=X.drop(columns='y')
y=df['y']

# %%
X
# Out:
#        age  balance  day  duration  campaign  pdays  previous  job_admin  \
# 0       58     2143    5       261         1     -1         0          0
# 1       44       29    5       151         1     -1         0          0
# 2       33        2    5        76         1     -1         0          0
# 3       47     1506    5        92         1     -1         0          0
# 4       33        1    5       198         1     -1         0          0
# ...    ...      ...  ...       ...       ...    ...       ...        ...
# 45206   51      825   17       977         3     -1         0          0
# 45207   71     1729   17       456         2     -1         0          0
# 45208   72     5715   17      1127         5    184         3          0
# 45209   57      668   17       508         4     -1         0          0
# 45210   37     2971   17       361         2    188        11          0
#
#        job_blue  job_entrepreneur  ...  month_dec  month_feb  month_jan  \
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 45206    1
# 45207    1
# 45208    1
# 45209    0
# 45210    0
# Name: y, Length: 45211, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.distplot(X,hist=True,kde=True)

# %%
#appling sampling techniques

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros=RandomOverSampler(random_state=42)

# %%
X_res, y_res = ros.fit_resample(X, y)

# %%
print(len(X_res))
# Out:
# 79844

# %%
print(len(y_res))
# Out:
# 79844

# %%
len(X)
# Out:
# 45211

# %%
len(y)
# Out:
# 45211

# %%
df['y'].value_counts()
# Out:
# 0    39922
# 1     5289
# Name: y, dtype: int64

# %%
y_res.value_counts()
# Out:
# 0    39922
# 1    39922
# Name: y, dtype: int64

# %%
X_res
# Out:
#        age  balance  day  duration  campaign  pdays  previous  job_admin  \
# 0       58     2143    5       261         1     -1         0          0
# 1       44       29    5       151         1     -1         0          0
# 2       33        2    5        76         1     -1         0          0
# 3       47     1506    5        92         1     -1         0          0
# 4       33        1    5       198         1     -1         0          0
# ...    ...      ...  ...       ...       ...    ...       ...        ...
# 79839   53     1796   16       295         1     91         2          1
# 79840   43        0   14      1153         3     -1         0          0
# 79841   38      536   22       248         1     -1         0          0
# 79842   53     1004   13       393         1     84         1          0
# 79843   42      757   10       154         1     -1         0          0
#
#        job_blue  job_entrepreneur  ...  month_dec  month_feb  month_jan  \
# ...

# %%
 from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
lr=LogisticRegression(C=0.0001)

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=0.0001)

# %%
lr.score(X_train,y_train)
# Out:
# 0.8062778864970646

# %%
lr.score(X_test,y_test)
# Out:
# 0.7988602918153923

# %%
for c in np.arange(-5, 5):
    lr = LogisticRegression(C=10.**c, random_state=1) 
    lr.fit(X_train, y_train)
    print ('train:',lr.score(X_train,y_train))
    print ('test:',lr.score(X_test,y_test))
    print ('C:',10.0**c)
    print ()
# Out:
# train: 0.7646183953033268
# test: 0.7549627403093494
# C: 1e-05
#
# train: 0.8062778864970646
# test: 0.7988602918153923
# C: 0.0001
#
# train: 0.8147788649706458
# test: 0.8066253365896424
# C: 0.001
#
# train: 0.8152641878669276
# test: 0.807314171206713
# C: 0.01
#
# train: 0.8150293542074364
# test: 0.80700106456259
# C: 0.1
#
# train: 0.8150450097847358
# test: 0.8069384432337654
# C: 1.0
#
# train: 0.8150450097847358
# test: 0.8069384432337654
# C: 10.0
#
# train: 0.8150450097847358
# test: 0.8069384432337654
# C: 100.0
#
# train: 0.8150450097847358
# test: 0.8069384432337654
# C: 1000.0
#
# train: 0.8150450097847358
# test: 0.8069384432337654
# C: 10000.0

# %%
#This model is working on this data set but is not too great.

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=42,ccp_alpha=0.001)

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.001, random_state=42)

# %%
clf.score(X_train,y_train)
# Out:
# 0.8353659491193738

# %%
clf.score(X_test,y_test)
# Out:
# 0.830045713570042

# %%
clf = DecisionTreeClassifier()
path = clf.cost_complexity_pruning_path(X_train, y_train)
path
# Out:
# {'ccp_alphas': array([0.00000000e+00, 1.01623923e-05, 1.02940782e-05, ...,
#         2.17245852e-02, 2.54650607e-02, 1.00339689e-01]),
#  'impurities': array([0.00000000e+00, 3.04871768e-05, 6.13694115e-05, ...,
#         3.74192381e-01, 3.99657442e-01, 4.99997131e-01])}

# %%
ccp_alphas, impurities = path.ccp_alphas, path.impurities

plt.figure(figsize=(10, 6))
plt.plot(ccp_alphas, impurities)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier( random_state=0)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param_dist={'n_estimators':[int(x) for x in np.linspace(start=10,stop=150,num=15)],
            'max_features':['auto','sqrt'],
            'min_samples_leaf':[1,2,3,4,5,6,7,8,9],
            'max_depth':[int(x) for x in np.linspace(2,30,10)],
            'min_samples_split':[int(x) for x in np.linspace(2,15,5)]}

# %%
def hyper(rfr,param,X,y):
    random=RandomizedSearchCV(estimator=rfr,param_distributions=param,n_jobs=-1,cv=5,n_iter=20)
    random.fit(X,y)
    ht_params=random.best_params_
    ht_score=random.best_score_
    return ht_params,ht_score

# %%
parameters,scores=hyper(clf,param_dist,X,y)

# %%
parameters
# Out:
# {'n_estimators': 1100,
#  'min_samples_split': 15,
#  'min_samples_leaf': 9,
#  'max_features': 'auto',
#  'max_depth': 2}

# %%
scores
# Out:
# 0.8830151956773266

# %%
clf = RandomForestClassifier(n_estimators=1100,min_samples_split=15,min_samples_leaf=9,max_features='auto',max_depth=2, random_state=0)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=2, min_samples_leaf=9, min_samples_split=15,
#                        n_estimators=1100, random_state=0)

# %%
clf.score(X_train,y_train)
# Out:
# 0.7538473581213307

# %%
clf.score(X_test,y_test)
# Out:
# 0.7500782766610308

# %%
from sklearn.svm import SVC
classifier=SVC(kernel='rbf')
classifier.fit(X_train,y_train)
# Out:
# SVC()

# %%
classifier.score(X_train,y_train)
# Out:
# 0.888187866927593

# %%
classifier.score(X_test,y_test)
# Out:
# 0.8761976329137704

# %%
from sklearn.svm import SVC
classifier=SVC(kernel='poly')
classifier.fit(X_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
classifier.score(X_train,y_train)
# Out:
# 0.8887045009784735

# %%
classifier.score(X_test,y_test)
# Out:
# 0.8761350115849458

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8761350115849458

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
clf = AdaBoostClassifier(n_estimators=14, random_state=0)
clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(n_estimators=14, random_state=0)

# %%
clf.score(X_train,y_train)
# Out:
# 0.8072485322896282

# %%
clf.score(X_test,y_test)
# Out:
# 0.8030559208466403

# %%
params_dist={'n_estimators':[int(x) for x in np.linspace(10,100,20)]}

# %%
parameters,scores=hyper(clf,params_dist,X,y)

# %%
parameters
# Out:
# {'n_estimators': 14}

# %%
scores
# Out:
# 0.7982329699902916

# %%
from sklearn.model_selection import GridSearchCV

# %%
def hype(este,param_grid,X,y):
    grid=GridSearchCV(estimator=clf,param_grid=params_dist,n_jobs=-1)
    grid.fit(X,y)
    return grid.best_params_

# %%
parameter=hype(clf,params_dist,X,y)

# %%
parameter
# Out:
# {'n_estimators': 14}

# %%
y_pred=clf.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8030559208466403

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier(n_estimators=130,min_samples_split=2,min_samples_leaf=1,max_features='auto',max_depth=2)

# %%
gbc.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(max_depth=2, max_features='auto', n_estimators=130)

# %%
parameters,scores=hyper(gbc,param_dist,X,y)

# %%
parameters
# Out:
# {'n_estimators': 130,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 2}

# %%
scores
# Out:
# 0.7603211038963659

# %%
gbc.score(X_train,y_train)
# Out:
# 0.8480469667318983

# %%
gbc.score(X_test,y_test)
# Out:
# 0.8401903688396267
